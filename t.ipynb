# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------------
# absl-py                      1.3.0
# addict                       2.4.0
# aiofiles                     22.1.0
# aiohttp                      3.8.3
# aiosignal                    1.2.0
# ajsonrpc                     1.2.0
# aniso8601                    9.0.1
# anyio                        3.6.2
# appdirs                      1.4.4
# asttokens                    2.0.5
# astunparse                   1.6.3
# async-timeout                4.0.2
# attrs                        22.2.0
# backbone                     0.6.0
# backcall                     0.2.0
# backoff                      2.2.1
# beautifulsoup4               4.11.1
# blinker                      1.4
# bottle                       0.12.23
# brotlipy                     0.7.0
# cachetools                   5.2.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# ...
